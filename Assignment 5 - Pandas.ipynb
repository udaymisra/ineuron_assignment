# %% [markdown]
# # Assignment 5 Questions

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### Task 1:
#
# Read the dataset from the bellow link
#
# url = https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#url=" "https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv"
df=pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")
df.head()
# Out:
#    year     name   percent  sex
# 0  1880     John  0.081541  boy
# 1  1880  William  0.080511  boy
# 2  1880    James  0.050057  boy
# 3  1880  Charles  0.045167  boy
# 4  1880   George  0.043292  boy

# %% [markdown]
# Questions

# %% [markdown]
# 1. Delete unnamed columns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv', index_col=0)
print(df.head())
# Out:
#          name   percent  sex
# year
# 1880     John  0.081541  boy
# 1880  William  0.080511  boy
# 1880    James  0.050057  boy
# 1880  Charles  0.045167  boy
# 1880   George  0.043292  boy

# %% [markdown]
# 2. Show the distribution of male and female

# %%
by_sex=df.groupby("sex")
by_sex.size().plot(kind="bar")

# %% [markdown]
# 3. Show the top 5 most preferred names

# %%
n=5
df['name'].value_counts()[:n].index.tolist()
# Out:
# ['Jessie', 'Leslie', 'Guadalupe', 'Jean', 'Lee']

# %% [markdown]
# 4. What is the median name occurence in the dataset

# %%
ave = df.groupby('name').median()
ave
# Out:
#             year   percent
# name
# Aaden     2008.0  0.000442
# Aaliyah   2001.0  0.001694
# Aarav     2008.0  0.000101
# Aaron     1948.5  0.000703
# Ab        1882.0  0.000042
# Abagail   2003.5  0.000134
# Abb       1890.0  0.000046
# Abbey     1993.0  0.000223
# Abbie     1925.5  0.000159
# Abbigail  2001.5  0.000275
# Abbott    1884.0  0.000044
# Abby      1976.0  0.000163
# Abdiel    2008.0  0.000092
# Abdul     1982.5  0.000060
# Abdullah  2002.5  0.000097
# Abe       1918.5  0.000253
# Abel      1944.5  0.000107
# Abelardo  1972.0  0.000041
# Abie      1889.0  0.000042
# Abigail   1966.0  0.000130
# Abigale   2003.0  0.000138
# Abigayle  2003.0  0.000165
# Abner     1907.5  0.000126
# Abraham   1944.0  0.000474
# Abram     1925.0  0.000087
# Abril     2003.0  0.000131
# Ace       1891.0  0.000073
# Acey      1886.0  0.000042
# Achsah    1881.0  0.000040
# Acie      1902.0  0.000062
# ...          ...       ...
# Zela      1897.0  0.000048
# Zelda     1925.0  0.000115
# Zelia     1892.0  0.000055
# Zella     1915.0  0.000265
# Zelma     1917.5  0.000282
# Zelpha    1898.0  0.000056
# Zena      1898.0  0.000061
# Zenas     1885.0  0.000052
# Zeno      1894.0  0.000072
# Zenobia   1909.0  0.000057
# Zeta      1897.0  0.000048
# Zetta     1894.0  0.000075
# Zettie    1898.0  0.000059
# Zhane     1994.5  0.000153
# Zigmund   1917.5  0.000052
# Zillah    1886.0  0.000059
# Zilpah    1881.0  0.000091
# Zilpha    1886.0  0.000059
# Zina      1962.5  0.000062
# Zion      2005.0  0.000420
# Zita      1903.0  0.000055
# Zoa       1886.0  0.000074
# Zoe       1932.0  0.000083
# Zoey      2001.5  0.000507
# Zoie      2003.0  0.000224
# Zola      1910.5  0.000136
# Zollie    1890.5  0.000055
# Zona      1910.5  0.000086
# Zora      1909.0  0.000169
# Zula      1906.0  0.000196
#
# [6782 rows x 2 columns]

# %% [markdown]
# 5. Distribution of male and female born count by states

# %%
# States not available in data set 

df.groupby(['year','sex']).count()
# Out:
#            name  percent
# year sex
# 1880 boy   1000     1000
#      girl  1000     1000
# 1881 boy   1000     1000
#      girl  1000     1000
# 1882 boy   1000     1000
#      girl  1000     1000
# 1883 boy   1000     1000
#      girl  1000     1000
# 1884 boy   1000     1000
#      girl  1000     1000
# 1885 boy   1000     1000
#      girl  1000     1000
# 1886 boy   1000     1000
#      girl  1000     1000
# 1887 boy   1000     1000
#      girl  1000     1000
# 1888 boy   1000     1000
#      girl  1000     1000
# 1889 boy   1000     1000
#      girl  1000     1000
# 1890 boy   1000     1000
#      girl  1000     1000
# 1891 boy   1000     1000
#      girl  1000     1000
# 1892 boy   1000     1000
#      girl  1000     1000
# 1893 boy   1000     1000
#      girl  1000     1000
# 1894 boy   1000     1000
#      girl  1000     1000
# ...         ...      ...
# 1994 boy   1000     1000
#      girl  1000     1000
# 1995 boy   1000     1000
#      girl  1000     1000
# 1996 boy   1000     1000
#      girl  1000     1000
# 1997 boy   1000     1000
#      girl  1000     1000
# 1998 boy   1000     1000
#      girl  1000     1000
# 1999 boy   1000     1000
#      girl  1000     1000
# 2000 boy   1000     1000
#      girl  1000     1000
# 2001 boy   1000     1000
#      girl  1000     1000
# 2002 boy   1000     1000
#      girl  1000     1000
# 2003 boy   1000     1000
#      girl  1000     1000
# 2004 boy   1000     1000
#      girl  1000     1000
# 2005 boy   1000     1000
#      girl  1000     1000
# 2006 boy   1000     1000
#      girl  1000     1000
# 2007 boy   1000     1000
#      girl  1000     1000
# 2008 boy   1000     1000
#      girl  1000     1000
#
# [258 rows x 2 columns]

# %% [markdown]
# #### Task 2:
#
# We have the min and max temperatures in a city In India for each months of the year. We
# would like to find a function to describe this and show it graphically, the dataset given below.
#
#     Task:
#     1. fitting it to the periodic function
#     2. plot the fit
#
#     Data
#     Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#     Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
import numpy as np

temp_max = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
temp_min = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])

import matplotlib.pyplot as plt
months = np.arange(12)
plt.plot(months, temp_max, 'go')
plt.plot(months, temp_min, 'co')
plt.xlabel('Month')
plt.ylabel('Min and max temperature')
# Out:
# Text(0, 0.5, 'Min and max temperature')
